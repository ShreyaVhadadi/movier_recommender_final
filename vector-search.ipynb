# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter, SentenceTransformersTokenTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
import pandas as pd
movies = pd.read_csv('movies_cleaned_final4.csv')

# %%
movies
# Out:
#            id                                              title  \
# 0      838513                                POV: Points Of View
# 1      370005                                              Storm
# 2      590634                            Friended: Deep Dark Web
# 3      832873                                 Feedback Sketch #1
# 4      592976                                      Verdi: Otello
# ...       ...                                                ...
# 14995  302694                                           Bridgend
# 14996  771282                                 Imaginary Portrait
# 14997  505538                   Oscar D' Leon - Live From London
# 14998   24613                                            Kurbaan
# 14999  717022  Go! Anpanman: Nanda and Runda from the Star of...
#
#                                     genres  \
# 0                                      NaN
# 1                           Drama-TV Movie
# 2                                   Comedy
# ...

# %%
movies['tagged_overview1']
# Out:
# 0        838513 Los Angeles 2025. As an Insighter you h...
# 1        370005 An elderly gentleman  lives alone with ...
# 2        590634 Marcus has invented the ultimate dating...
# 3        832873 Multiple clips of video feedback (a Min...
# 4        592976 Like an outcry the elemental force of t...
#                                ...
# 14995    302694 Since 2007 dozens of young people have ...
# 14996    771282 Through the creation of a family portra...
# 14997    505538 After several undistinguished albums in...
# 14998    24613 When a handsome young Indian couple (Sai...
# 14999    717022 The super pastry hero must help a selfi...
# Name: tagged_overview1, Length: 15000, dtype: object

# %%
movies["tagged_overview1"].to_csv("movies_tagged_overview1.txt",
                                 index=False,
                                 header=False)

# %%
raw_documents2 = TextLoader("movies_tagged_overview1.txt").load()
text_splitter = CharacterTextSplitter(chunk_size=0,chunk_overlap=0)
documents = text_splitter.split_documents(raw_documents2)

# %%
text_splitter1 = CharacterTextSplitter(chunk_size=0,chunk_overlap=0,separator="\n")
documents2 = text_splitter1.split_documents(raw_documents2)
# Out:
# Created a chunk of size 694, which is longer than the specified 0
# Created a chunk of size 944, which is longer than the specified 0
# Created a chunk of size 228, which is longer than the specified 0
# Created a chunk of size 469, which is longer than the specified 0
# Created a chunk of size 762, which is longer than the specified 0
# Created a chunk of size 374, which is longer than the specified 0
# Created a chunk of size 451, which is longer than the specified 0
# Created a chunk of size 261, which is longer than the specified 0
# Created a chunk of size 419, which is longer than the specified 0
# Created a chunk of size 289, which is longer than the specified 0
# Created a chunk of size 205, which is longer than the specified 0
# Created a chunk of size 176, which is longer than the specified 0
# Created a chunk of size 304, which is longer than the specified 0
# Created a chunk of size 220, which is longer than the specified 0
# ...

# %%
documents2[0]
# Out:
# Document(metadata={'source': 'movies_tagged_overview1.txt'}, page_content='838513 Los Angeles 2025. As an Insighter you have been requested to review Case File 456.23 at the Federal Drone Headquarters. The case centers around 21-year-old Cassius Moore a gifted Black coder who qualifies for early release under a new drone-surveillance program after serving two years in prison for biometric hacking. In this program the government assigns F.E.N.I.X. AI--a drone that is equipped with artificial intelligence and weapons to record Cassius’ every move. Follow F.E.N.I.X. and the former engineering student as they navigate the world together. Your task is to evaluate how machine-driven data and human driven biases impact the algorithms and outcomes in law enforcement.')

# %%
db_movies=Chroma.from_documents(
    documents2,
    embedding=OpenAIEmbeddings())

# %%
query="A movie about Magic"
movie=db_movies.similarity_search(query, k= 5)
movie
# Out:
# [Document(id='6ffdc7e6-72da-4aca-8457-64fa823301e4', metadata={'source': 'movies_tagged_overview1.txt'}, page_content='773793 The Magic History Of Cinema is an international documentary showcasing magic and movies long continued history and explores how the origins of cinema are closely linked to the conjurors and illusionists of the early 20th century and how those ties continue with todays top filmmakers and magicians.'),
# ...

# %%
movies[movies["id"]==int(movie[0].page_content.split()[0].strip())]
# Out:
#           id                        title       genres  \
# 5557  773793  The Magic History of Cinema  Documentary
#
#                                                overview  vote_average  \
# 5557  The Magic History Of Cinema is an internationa...           0.0
#
#       movie_age                                   tagged_overview1
# 5557        7.8  773793 The Magic History Of Cinema is an inter...

# %%
def retrieve_semantic_recommendations(query:str,top_k:int=3)->pd.DataFrame:
    recs=db_movies.similarity_search(query, k= 10)
    movie_list = []

    for i in range(0,len(recs)):
        movie_list+=[int(recs[i].page_content.strip('"').split()[0])]

    return movies[movies["id"].isin(movie_list)].head(top_k)

# %%
retrieve_semantic_recommendations("A movie about cars")
# Out:
#           id             title  genres  \
# 6458  448494  18 Frames/Second     NaN
# 6966  626537     Night Driving     NaN
# 8393  569960      About Cinema  Comedy
#
#                                                overview  vote_average  \
# 6458  A movie about friendship the search for an ide...           1.0
# 6966  Back in 1957 Mort & Millie loaded the kids in ...           0.0
# 8393  Five kinonovell closely related to each other ...           0.0
#
#       movie_age                                   tagged_overview1
# 6458       15.2  448494 A movie about friendship the search for...
# 6966       67.2  626537 Back in 1957 Mort & Millie loaded the k...
# 8393        7.8  569960 Five kinonovell closely related to each...
