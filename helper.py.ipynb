# %%
import pandas as pd
import numpy as np

# %%
without_posters=pd.read_csv("movies_with_emotions.csv")

# %%
with_posters=pd.read_csv("movies_cleaned_final4.csv")

# %%
without_posters
# Out:
#            id                                              title  \
# 0      838513                                POV: Points Of View
# 1      370005                                              Storm
# 2      590634                            Friended: Deep Dark Web
# 3      832873                                 Feedback Sketch #1
# 4      592976                                      Verdi: Otello
# ...       ...                                                ...
# 15429  302694                                           Bridgend
# 15430  771282                                 Imaginary Portrait
# 15431  505538                   Oscar D' Leon - Live From London
# 15432   24613                                            Kurbaan
# 15433  717022  Go! Anpanman: Nanda and Runda from the Star of...
#
#                                     genres  \
# 0                                      NaN
# 1                           Drama-TV Movie
# 2                                   Comedy
# ...

# %%
with_posters
# Out:
#            id                                              title  \
# 0      838513                                POV: Points Of View
# 1      370005                                              Storm
# 2      590634                            Friended: Deep Dark Web
# 3      832873                                 Feedback Sketch #1
# 4      592976                                      Verdi: Otello
# ...       ...                                                ...
# 14995  302694                                           Bridgend
# 14996  771282                                 Imaginary Portrait
# 14997  505538                   Oscar D' Leon - Live From London
# 14998   24613                                            Kurbaan
# 14999  717022  Go! Anpanman: Nanda and Runda from the Star of...
#
#                                     genres  \
# 0                                      NaN
# 1                           Drama-TV Movie
# 2                                   Comedy
# ...

# %%
final_with_posters1 = pd.merge(
    without_posters,
    with_posters[['id', 'poster_path']],
    on='id',
    how='left'
)

# %%
final_with_posters1
# Out:
#            id                                              title  \
# 0      838513                                POV: Points Of View
# 1      370005                                              Storm
# 2      590634                            Friended: Deep Dark Web
# 3      832873                                 Feedback Sketch #1
# 4      592976                                      Verdi: Otello
# ...       ...                                                ...
# 15973  302694                                           Bridgend
# 15974  771282                                 Imaginary Portrait
# 15975  505538                   Oscar D' Leon - Live From London
# 15976   24613                                            Kurbaan
# 15977  717022  Go! Anpanman: Nanda and Runda from the Star of...
#
#                                     genres  \
# 0                                      NaN
# 1                           Drama-TV Movie
# 2                                   Comedy
# ...

# %%
print(without_posters['id'].is_unique)
# Out:
# False

# %%
print(with_posters['id'].is_unique)
# Out:
# False

# %%
without_posters_unique = without_posters.drop_duplicates(subset=['id'])
with_posters_unique = with_posters.drop_duplicates(subset=['id'])
final_with_posters2 = pd.merge(
    without_posters_unique,
    with_posters_unique[['id', 'poster_path']],
    on='id',
    how='left'
)

# %%
final_with_posters2
# Out:
#            id                                              title  \
# 0      838513                                POV: Points Of View
# 1      370005                                              Storm
# 2      590634                            Friended: Deep Dark Web
# 3      832873                                 Feedback Sketch #1
# 4      592976                                      Verdi: Otello
# ...       ...                                                ...
# 14940  302694                                           Bridgend
# 14941  771282                                 Imaginary Portrait
# 14942  505538                   Oscar D' Leon - Live From London
# 14943   24613                                            Kurbaan
# 14944  717022  Go! Anpanman: Nanda and Runda from the Star of...
#
#                                     genres  \
# 0                                      NaN
# 1                           Drama-TV Movie
# 2                                   Comedy
# ...

# %%
print(without_posters['id'].nunique())
# Out:
# 14945

# %%
print(with_posters['id'].nunique())
# Out:
# 14945

# %%
final_dataset=final_with_posters2[~(final_with_posters2["simple_categories"].isna()) &
        ~(final_with_posters2["anger"].isna())
]

# %%
final_dataset
# Out:
#            id                                              title  \
# 0      838513                                POV: Points Of View
# 1      370005                                              Storm
# 2      590634                            Friended: Deep Dark Web
# 3      832873                                 Feedback Sketch #1
# 4      592976                                      Verdi: Otello
# ...       ...                                                ...
# 14940  302694                                           Bridgend
# 14941  771282                                 Imaginary Portrait
# 14942  505538                   Oscar D' Leon - Live From London
# 14943   24613                                            Kurbaan
# 14944  717022  Go! Anpanman: Nanda and Runda from the Star of...
#
#                                     genres  \
# 0                                      NaN
# 1                           Drama-TV Movie
# 2                                   Comedy
# ...

# %%
final_dataset.to_csv("final_dataset.csv",index=False)
